# %% [markdown]
# ### <u> Intro </u>
#
#  This notebook isnt as polished as the other code <br/>
#  It is purposly verbose and simple, we can build it into something more complex when/if needed <br/>
#  Currently it should be very easy to experiment with adding different numbers of hidden layers into the network <br/>
#  Also it will be very easy to edit to change number of nodes/epochs/do cross validation etc etc <br/>
#
# ### <u> Quick run through </u>
#
#  It is a simple MLP model - though I think MLP is probably the most sensible to use (we should ask Mikey if he knows of anything more exotic that would make sense using) <br/>
#  I think more complex models would be a waste of time, they may perform slightly better but not sure its worth it - again we should ask Mikey his opinion on that <br/>
#
#  It takes in a data set of a given size, and essentially does a multi-output regression <br/>
#  Use the nanomei_big_data_generator.py script to create data sets of given sizes - you only need to change the 'data_steps' parameter and then the file names it saves too <br/>
#  In this version of the scrip I am using a reduced data set created from 100 'data_steps' in the generator script <br/>
#  It runs very fast on my mac  <br/>
#
# Results are plotted at the bottom.
#
# ### <u> What Im worried about </u>
#
# Dont know why I didnt think of this earlier but I think the complex numbers arent being handled properly. <br/>
# Need to look into this. <br/>
# Fist think I think is just break the complex numbers up into real/imaginary and handle them seperatley <br/>

# %%
import pickle
import math
import numpy as np
from scipy.special import jv, yv, jve, yve
import matplotlib.pyplot as plt
import pandas as pd
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import RepeatedKFold
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# %%
#root = '/Users/sam/Documents/Nano-Mei'
root = '/Users/wsb/Library/CloudStorage/OneDrive-SharedLibraries-UniversityofSouthampton/Phase retrieval with neural nets - Documents/nanoparticle Mie scattering project/mie Python code/wsb working'

# Use the with statement to open the file and automatically close it when you're done
with open("{}/Iperp_data_ReducedSet_100Steps.pickle".format(root), "rb") as file:
    # Load the data from the file
    my_dict = pickle.load(file)

# %%
# Break apart keys and values from the dictionary 
keys_list = list(my_dict.keys())
values_list = list(my_dict.values())

print(keys_list[:3])
foo = values_list[0]
print(foo[:3])
#try to have a look at the first set of values
plt.figure()
plt.plot(np.log(values_list[0]))
plt.show()

# Break the tuples in keys list into corresponding index and radius values
index = [a for a, _ in keys_list]
radius = [b for _, b in keys_list]

# Ratio for test/train split
ratio = int(0.8 * len(index))

# Turning lists into numpy arrays 
np_index = np.array(index)
np_radius = np.array(radius)
np_IPerp = np.array(values_list)

# Recombine index and radius in a more sensible manner
np_combined_y = np.column_stack((np_index,np_radius))

# Log IPerp
logged_np_IPerp_X = np.log(np_IPerp)

# Create test/train splits

X_train_logIPerp = logged_np_IPerp_X[:ratio]
Y_train_combinedRI = np_combined_y[:ratio]

X_test_logIPerp = logged_np_IPerp_X[ratio:]
Y_test_combinedRI = np_combined_y[ratio:]
# Out:
# [((1.3+1e-08j), 6e-06), ((1.3+1e-08j), 6.040404040404041e-06), ((1.3+1e-08j), 6.080808080808081e-06)]
# [4046122.99712739 3901676.36448041 3494213.01633334]

# %%
def build_model(input_shape, output_shape):
  # define the model
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.Input(shape=input_shape))
  model.add(tf.keras.layers.Dense(64, activation='relu'))
  model.add(tf.keras.layers.Dense(output_shape))
  model.compile(optimizer='adam', loss='mean_squared_error')
  return model

def train_model(model, X, y):
  model.fit(X, y, epochs=100)

def predict(model, X):
  y_pred = model.predict(X)
  return y_pred

def evaluate(model, X, y):
  y_pred = model.predict(X)
  mse = tf.keras.losses.mean_squared_error(y, y_pred)
  print('THE Mean squared error:', mse)

# %%
# build the model
input_shape = (500,)
output_shape = 2
model = build_model(input_shape, output_shape)

# train the model
X_train = X_train_logIPerp  # training data, shape (n_samples, 500)
y_train = Y_train_combinedRI  # training labels, shape (n_samples, 2)
train_model(model, X_train, y_train)

# %%
# use the trained model to make predictions
X_test = X_test_logIPerp  # test data, shape (n_samples, 500)
y_pred = predict(model, X_test)

# evaluate the model's performance
y_test = Y_test_combinedRI
evaluate(model, X_test, y_test)
# Out:
# Epoch 1/100
#  32/250 [==>...........................] - ETA: 0s - loss: 9.0604
# 2023-01-09 15:01:13.939880: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 250/250 [==============================] - 1s 3ms/step - loss: 1.7984
# Epoch 2/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3883
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2486
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1525
# Epoch 5/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1281
# Epoch 6/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0914
# Epoch 7/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0785
# Epoch 8/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0685
# Epoch 9/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0492
# Epoch 10/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0460
# Epoch 11/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0399
# Epoch 12/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0550
# Epoch 13/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0345
# Epoch 14/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0362
# Epoch 15/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0399
# Epoch 16/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0233
# Epoch 17/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0294
# Epoch 18/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0273
# Epoch 19/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0208
# Epoch 20/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0249
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0200
# Epoch 22/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0169
# Epoch 23/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0176
# Epoch 24/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0148
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0146
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0151
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0165
# Epoch 28/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0114
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0126
# Epoch 30/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0131
# Epoch 31/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0089
# Epoch 32/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0093
# Epoch 33/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0064
# Epoch 34/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0123
# Epoch 35/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0070
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0075
# Epoch 37/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0046
# Epoch 38/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0059
# Epoch 39/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0060
# Epoch 40/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0062
# Epoch 41/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0042
# Epoch 42/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0035
# Epoch 43/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0055
# Epoch 44/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0043
# Epoch 45/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0029
# Epoch 46/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0038
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0026
# Epoch 48/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0023
# Epoch 49/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0032
# Epoch 50/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0019
# Epoch 51/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0026
# Epoch 52/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0016
# Epoch 53/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0025
# Epoch 54/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0013
# Epoch 55/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0016
# Epoch 56/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0016
# Epoch 57/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0011
# Epoch 58/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0012
# Epoch 59/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0013
# Epoch 60/100
# 250/250 [==============================] - 1s 3ms/step - loss: 9.7021e-04
# Epoch 61/100
# 250/250 [==============================] - 1s 3ms/step - loss: 9.7679e-04
# Epoch 62/100
# 250/250 [==============================] - 1s 3ms/step - loss: 8.7614e-04
# Epoch 63/100
# 250/250 [==============================] - 1s 3ms/step - loss: 9.0686e-04
# Epoch 64/100
# 250/250 [==============================] - 1s 3ms/step - loss: 9.9607e-04
# Epoch 65/100
# 250/250 [==============================] - 1s 3ms/step - loss: 7.3310e-04
# Epoch 66/100
# 250/250 [==============================] - 1s 3ms/step - loss: 7.7669e-04
# Epoch 67/100
# 250/250 [==============================] - 1s 3ms/step - loss: 6.8326e-04
# Epoch 68/100
# 250/250 [==============================] - 1s 3ms/step - loss: 6.8596e-04
# Epoch 69/100
# 250/250 [==============================] - 1s 3ms/step - loss: 7.5745e-04
# Epoch 70/100
# 250/250 [==============================] - 1s 4ms/step - loss: 4.9788e-04
# Epoch 71/100
# 250/250 [==============================] - 1s 3ms/step - loss: 5.7388e-04
# Epoch 72/100
# 250/250 [==============================] - 1s 3ms/step - loss: 6.1520e-04
# Epoch 73/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.9849e-04
# Epoch 74/100
# 250/250 [==============================] - 1s 3ms/step - loss: 5.0890e-04
# Epoch 75/100
# 250/250 [==============================] - 1s 3ms/step - loss: 5.4109e-04
# Epoch 76/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.6689e-04
# Epoch 77/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.5155e-04
# Epoch 78/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.9001e-04
# Epoch 79/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.2649e-04
# Epoch 80/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.9433e-04
# Epoch 81/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.0779e-04
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.3053e-04
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.8347e-04
# Epoch 84/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.1013e-04
# Epoch 85/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.4505e-04
# Epoch 86/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.8081e-04
# Epoch 87/100
# 250/250 [==============================] - 1s 3ms/step - loss: 4.9606e-04
# Epoch 88/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.1795e-04
# Epoch 89/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.9600e-04
# Epoch 90/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.2734e-04
# Epoch 91/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.0085e-04
# Epoch 92/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.9832e-04
# Epoch 93/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.3782e-04
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 3.0263e-04
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.2113e-04
# Epoch 96/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.6197e-04
# Epoch 97/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.2516e-04
# Epoch 98/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.6408e-04
# Epoch 99/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.7089e-04
# Epoch 100/100
# 250/250 [==============================] - 1s 3ms/step - loss: 2.3983e-04
# 63/63 [==============================] - 0s 2ms/step
# 36/63 [================>.............] - ETA: 0s
# 2023-01-09 15:02:34.473545: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 63/63 [==============================] - 0s 1ms/step
# THE Mean squared error: tf.Tensor([0.00229062 0.00138952 0.00458648 ... 0.00541354 0.00119969 0.00207169], shape=(2000,), dtype=float32)

# %%
# calculate the difference between the expected and predicted values

#let's just examine these variables...
print(y_test[0,:], y_pred[0,:])
difference = y_test - y_pred

# plot the difference
plt.plot(y_test, label = 'y_test')
plt.plot(y_pred, label = 'y_pred')
plt.xlabel('Sample index')
plt.ylabel('Difference')
plt.legend()
plt.show()
# try a plot of one against the other
plt.figure()
plt.plot(y_test[:,0], y_pred[:,0],'.')
plt.show()
# Out:
# [1.7040404e+00+1.e-08j 6.0000000e-06+0.e+00j] [1.6363623e+00 9.5923338e-04]

# %%
# Out:
# 2000

# %%
y_pred
# Out:
# array([[ 1.450726  , -0.56007147],
#        [ 1.7068638 , -0.42179063],
#        [ 1.6634856 ,  0.24886559],
#        ...,
#        [ 1.4351262 , -0.15155698],
#        [ 1.5059663 , -0.16859151],
#        [ 1.4756153 , -0.0732713 ]], dtype=float32)

# %%
y_test
# Out:
# array([[1.70404040e+00+1.e-08j, 6.00000000e-06+0.e+00j],
#        [1.70404040e+00+1.e-08j, 6.04040404e-06+0.e+00j],
#        [1.70404040e+00+1.e-08j, 6.08080808e-06+0.e+00j],
#        ...,
#        [1.80000000e+00+1.e-08j, 9.91919192e-06+0.e+00j],
#        [1.80000000e+00+1.e-08j, 9.95959596e-06+0.e+00j],
#        [1.80000000e+00+1.e-08j, 1.00000000e-05+0.e+00j]])
