# %%
import matplotlib.pyplot as plt
import numpy as np
import mie_data_generator_function as mdg  #doesn't work unless you have the 'mdg' bit

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
theta, Icalc = mdg.generate_data(1.5, 8e-6)
fig, ax = plt.subplots()
ax.plot(theta, np.log10(Icalc))
plt.show()
# Out:
# Entering gen_data
# x= 79.43344256864205
# n= 99
# 99 79.43344256864205
